# %% [markdown]
# <h1>Szöveg generálás LSTM alkalmazásával<h1>

# %% [markdown]
# ### **Parókai Dominik - R9XG1T**

# %% [markdown]
# ## Feladat rövid leírása
# A feladat során LSTM neurális háló segítségével képzünk szöveget Dan Brown: The Da Vinci Code  című művét felhasználva.

# %% [markdown]
# ### Beimportáljuk a szükséges könyvtárakat

# %%
import numpy as np
import pandas as pd
import keras
import os

# %% [markdown]
# ### A kezdeti szövegfájl betöltése és elemzése

# %%
with open("../content/sample_data/davincicode.txt", "r", encoding="utf8") as f:
    text = f.read().lower()
print('Szöveg hossza:',len(text))
# Out:
# Szöveg hossza: 90761

# %% [markdown]
# ### Karaktersorozatok vektorizálása

# %%
maxlen = 40

step = 3

sentences = []

next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))
chars = sorted(list(set(text)))
print('Unique characters', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 30241
# Unique characters 53
# Vectorization...
# <ipython-input-28-d35002ee0543>:20: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-28-d35002ee0543>:21: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %% [markdown]
# ## A hálózat kiépítése
# ### Single-layer LSTM modell a következő karakter megjóslására

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# ### Model Compilation Konfigurálása

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.

# %% [markdown]
# ### Function, amely a modell előrejelzései alapján mintát vesz a következő karakterből

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds)/ temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ### Szöveg Generáló Loop

# %%
import random
import sys

for epoch in range(1, 30):
    print('\n epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('Generating with seed:  "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('\n temperature:', temperature)
        sys.stdout.write(generated_text)

        for i in range(100):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
# Out:
#  epoch 1
# 237/237 [==============================] - 24s 101ms/step - loss: 2.3938
# Generating with seed:  "urch's elimination of the sacred feminin"
#
#  temperature: 0.2
# urch's elimination of the sacred feminin the the the the the the the the the coule the the the the s an the the the the the the was an the
#
#  temperature: 0.5
#  an the the the the the the was an the
#
#
#
#
#
#
#
# "
#
# "
#
# the the we tho nof an ae tol pe feco the cos the the ad he the mad an we al the fal t
#  temperature: 1.0
# the the ad he the mad an we al the fal th ves inin ocess bota alod le de be watl emr.e"
# lito" ae nzt lathett —mviling mes hr iri s ofrial t
#  temperature: 1.2
# t lathett —mviling mes hr iri s ofrial tes aomec wstoted ? oas.
# oade.- "eles
# vowine, "ocl'n ea, mhautre coe. "al. "eing havy rous ontyepto
#  epoch 2
# 237/237 [==============================] - 23s 95ms/step - loss: 2.3441
# Generating with seed:  "w commanding seemed
# impossible. "but th"
#
#  temperature: 0.2
# w commanding seemed
# impossible. "but the the the saring an and the was the the bat an the salled an the the the sared the the the pare the
#  temperature: 0.5
#  the the the sared the the the pare the the thit and te sad ag an san the s and sinlt he the fas ion
#
#
#
#
#
# halis sant rhe crillant becdres o
#  temperature: 1.0
#
#
#
#
#
#
# halis sant rhe crillant becdres owes inme.in"'tldaln trlaris ing h rangithed ncabd bhald the the dherandrraprelsiss ot kinithe  so- t
#  temperature: 1.2
# the dherandrraprelsiss ot kinithe  so- tein tnurry soind the
# sevid she ha mas pavgopk be is
# ntmise
# r aacera, danysad hin baa s uicersad.a
#  epoch 3
# 237/237 [==============================] - 23s 98ms/step - loss: 2.3048
# Generating with seed:  " he somehow preferred the idea of devil "
#
#  temperature: 0.2
#  he somehow preferred the idea of devil the cored the seastere sared the the sared the che the cores anthe fared anstone has anthe sared of
#  temperature: 0.5
#  anthe fared anstone has anthe sared of carast the fevese sound on coule the arede wasted antersiste she mecas spethe che chere the chistore
#  temperature: 1.0
#  she mecas spethe che chere the chistores prictiam cemersichest domessen. balwecheelee
# datheytho fisgelpoclsthes veilward ferkek6ye4isipope
#  temperature: 1.2
# sgelpoclsthes veilward ferkek6ye4isipopeqiw? —afize" jowcaing
# the hemsthedesurgepwtafee ansputhivope."bwpaas athorpusyribvesxwycad fath aol
#  epoch 4
# 237/237 [==============================] - 23s 97ms/step - loss: 2.2710
# Generating with seed:  "s that mr. sauniere dedicated his life t"
#
#  temperature: 0.2
# s that mr. sauniere dedicated his life the the sars and the sare the the s and the the s and the pare the sald the the the sing the sed the
#  temperature: 0.5
# e the sald the the the sing the sed the the the selt the feris semmis and he ton as momen the
#
#
#
# sangd on ting on the sind has and an for c
#  temperature: 1.0
# ngd on ting on the sind has and an for coong th pringite ppulacad.
#
# f ast the 9ply to gar cas bond limd cro ku fuxem mye the
# hared mins e
#  temperature: 1.2
# limd cro ku fuxem mye the
# hared mins eesk niy velavthay "wab achsonge
# y huwes. tico ma's
#
#
# tgoy .o w semped fe hivid.m.
# afa thi abdy ga
#  epoch 5
# 237/237 [==============================] - 25s 104ms/step - loss: 2.2413
# Generating with seed:  "ouvre and was
# huddled over an audio con"
#
#  temperature: 0.2
# ouvre and was
# huddled over an audio conthe the salle the pared the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  temperature: 0.5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lous mermers singdon at he
# ponterisis ald the leris.
#
# "stoorting us mathe the anded he the wald of
#  temperature: 1.0
# orting us mathe the anded he the wald of't tuep
# calymermopiinis wrwuss, aint's
# silusivedsad wi still yin dathat theppeacally a hu meders."
#  temperature: 1.2
# ll yin dathat theppeacally a hu meders." b2thein dounianisnuonlyith, 'mnledbled iod
# sealatture tirinvay ttaed shepul braonmo lafsenw oud ty
#  epoch 6
# 237/237 [==============================] - 24s 101ms/step - loss: 2.2136
# Generating with seed:  "the citroen up over the curb. the louvre"
#
#  temperature: 0.2
# the citroen up over the curb. the louvre sared the sared the cantere the ware the walled the fare the the core sande the the the the the cor
#  temperature: 0.5
# e the core sande the the the the the corthe
# "
# ntoure he bered int the the werute the thar the ath the wald his of wathe ned his the hall f
#  temperature: 1.0
# the wald his of wathe ned his the hall fodys
# theredt sirecty fiof maneat ones yuiul wean weon,
# bacpmintly to'vee sallleoneed, shoubed cho
#  temperature: 1.2
# pmintly to'vee sallleoneed, shoubed cho nraovipice thec 9umugad falbap,
# yte-ela teuplef
# e torongr. bsanir's and. "
# uad geaunto toale. an
#  epoch 7
# 237/237 [==============================] - 23s 96ms/step - loss: 2.1894
# Generating with seed:  "t's all too
# cryptic."
#
# fache frowned a"
#
#  temperature: 0.2
# t's all too
# cryptic."
#
# fache frowned and the pathe sand the sared the palled the prating the pored the was and the paring on the praris an
#  temperature: 0.5
#  the was and the paring on the praris and of tha lengene he the waris ap at the und the whar singers ad an oul the ared routhed in aked
# the
#  temperature: 1.0
#  ad an oul the ared routhed in aked
# them antd mishing
# fale thas mepgaricl syid wang hangd bbviagtry wloe cowa moun do dalper baale fosld f
#  temperature: 1.2
# y wloe cowa moun do dalper baale fosld fiuwk.
# aclknkmos cthee hlvincer atpede licky ut fotred
# agl waund serpain goby. hig." binso his poop
#  epoch 8
# 237/237 [==============================] - 24s 101ms/step - loss: 2.1661
# Generating with seed:  "his wide shoulders. he
# advanced with un"
#
#  temperature: 0.2
# his wide shoulders. he
# advanced with un andere the the bert and the cored the sangere the more the sound the paring the sound on the core t
#  temperature: 0.5
# sound the paring the sound on the core the warint of his wat of the arcing on
#
# the bore the the pith the sangion allotion this arithe the p
#  temperature: 1.0
# h the sangion allotion this arithe the puetone sothaid the allocos bly
# yeishinuly igd and f cceadlotistore coutuny
# lome poos.
#
# at hime th
#  temperature: 1.2
# tistore coutuny
# lome poos.
#
# at hime the marroich. paned,  swen)ong'e
#
# pumiclapld chicmec of ssladtyya satd ams, ic."."se"!o
# h't
# besid lo
#  epoch 9
# 237/237 [==============================] - 24s 101ms/step - loss: 2.1447
# Generating with seed:  "gh professor langdon might not be consid"
#
#  temperature: 0.2
# gh professor langdon might not be conside saring the porise forthe seating the mored a sarised the ared and the the the forting the cornite
#  temperature: 0.5
# red and the the the forting the cornite the
# cortenthing on the soured and wared and and of the sienton the lould the mous a fartice thatly
#  temperature: 1.0
# ton the lould the mous a fartice thatly edovad. wlitgd-irle. sisurkeis hendion avilt lomive
#
# fallitderet, buaked tyeloon nod eened had blly
#  temperature: 1.2
# deret, buaked tyeloon nod eened had bllyyd ig took?"
#
# langdun eachte,."." fyym'uth mowib eenpentiin chetyuks ax itsty. gisaons soud a mitur
#  epoch 10
# 237/237 [==============================] - 24s 100ms/step - loss: 2.1253
# Generating with seed:  "he longest
# building in europe, stretchi"
#
#  temperature: 0.2
# he longest
# building in europe, stretching of the conting the mound of the perice the poring on the corting the piche saring on the core the
#  temperature: 0.5
# corting the piche saring on the core the the cinating on geangor thal sinden the sistore forre
# to the coundere.
#
# "sanghe ald the forstond
#  temperature: 1.0
# he coundere.
#
# "sanghe ald the forstond ghing dool
# wan sthey wein alte porle. olangmoecl inglbole
# harwach misto.
#
#
# laviewable, clit iad m
#  temperature: 1.2
# harwach misto.
#
#
# laviewable, clit iad mepuby you mowl dorpenre urowp ppanting.
#
# staive qounm. "
# yoadd. horlonk.
#
# sitoungy ceumldodt pastk
#  epoch 11
# 237/237 [==============================] - 24s 101ms/step - loss: 2.1054
# Generating with seed:  "s the latter that angered fache more.
#
# "
#
#  temperature: 0.2
# s the latter that angered fache more.
#
#
#
#
#
#
# cheall of cher and the coring on the moring the corting on the cored the porting the pinger the
#  temperature: 0.5
#  on the cored the porting the pinger the
# chen in the racked the salned the langdon and the ablo the facle che prestit his of che corice the
#  temperature: 1.0
#  facle che prestit his of che corice the ghea lopuphe, hy thelly losk torlthe lof war emals ining os moplit colled the comepserirts bow ndt
#  temperature: 1.2
#  moplit colled the comepserirts bow ndt rericr..
# "diganus a wanof aangan intowat saimbedepiane.
# oins lloved rarpfreatq?an togechis rereach
#  epoch 12
# 237/237 [==============================] - 24s 99ms/step - loss: 2.0871
# Generating with seed:  " single spotlight on a portable pole sta"
#
#  temperature: 0.2
#  single spotlight on a portable pole star for he war sean the war seant of the pering on the mere pering of the pering of the mound of the m
#  temperature: 0.5
# ring of the pering of the mound of the meninot at his e for be tho gof an an hir sat ous sare se for suall bowron the pered the more.
#
#
#
#
#
#
#  temperature: 1.0
#  suall bowron the pered the more.
#
#
#
#
#
# in a doupsrat, beinin's bent hors ve cenfilyem alove. "ou't the loin per ars meit bed ol woulis. in
#  temperature: 1.2
# the loin per ars meit bed ol woulis. in alidsve's wad ewuite lous emeng ats onad wrich. — iof nitooiei an beaul, vor. "ouvijucol vo ced patk
#  epoch 13
# 237/237 [==============================] - 23s 96ms/step - loss: 2.0700
# Generating with seed:  "cabulary should have been clearer.
#
# now"
#
#  temperature: 0.2
# cabulary should have been clearer.
#
# now the macher a dere the corating on the perating of the cortere the seraco a dor the cortere the cort
#  temperature: 0.5
# re the seraco a dor the cortere the corting ermed the corle for an a most bo the
# "lous a deart of the merres ast mithen sounien parist bat
#  temperature: 1.0
# he merres ast mithen sounien parist bat lomglhing ane ore he prat balt gollare saantrry. " an deis, leass bis, bed."
#
# beas. dunfuriti.u rsu
#  temperature: 1.2
# leass bis, bed."
#
# beas. dunfuriti.u rsus's. nitd ow co fregpur icermarite. eiss ceripfoth bnls oftr aud, as hapencatiere's hoorthyagoon, on
#  epoch 14
# 237/237 [==============================] - 24s 100ms/step - loss: 2.0519
# Generating with seed:  "e. the three senechaux... and the grand "
#
#  temperature: 0.2
# e. the three senechaux... and the grand of the corning on the coring of the coon a dound on his a dond on a der and of the puriere the corne
#  temperature: 0.5
# nd on a der and of the puriere the corned his hus in store sard simon a cantithis dowt dould and the cand and ond wark and of the portoon co
#  temperature: 1.0
#  cand and ond wark and of the portoon coned, in d we tren winkpeofthe pinstly miots inevid, akn, blainquutacrecthed kacint on
#
# ho sound.
#
#
#  temperature: 1.2
# inquutacrecthed kacint on
#
# ho sound.
#
# ag-semre, in xisld edoft, howd. that kis anutas, het ollw9vit..
#
# d" h ollde omim "oun thitt ny giso
#  epoch 15
# 237/237 [==============================] - 23s 96ms/step - loss: 2.0360
# Generating with seed:  "if letting the triumph of this moment se"
#
#  temperature: 0.2
# if letting the triumph of this moment seath
#
# far has a far he mall of the cort and the prote the
#
# moun a farthe fache wat he
#
# the porice
#  temperature: 0.5
# moun a farthe fache wat he
#
# the porice the conting hem noue sean in a enterta had haring in the sacing he four ald and pere fat be the ange
#  temperature: 1.0
# ing he four ald and pere fat be the anger. fat ar intis?" crmaccrer ou ie of teavct.
#
# langeh. wenieg's lent yescmorve a mact intacle — foac
#  temperature: 1.2
# g's lent yescmorve a mact intacle — foach. with
#
#
# gazmeas wnangaviede ferthios, latunt, lidhexs
# murbec e-kevorir.
#
# ocleng a labtues. wric
#  epoch 16
# 237/237 [==============================] - 25s 106ms/step - loss: 2.0188
# Generating with seed:  "earlier events of the evening... how all"
#
#  temperature: 0.2
# earlier events of the evening... how all and the chople the ported the malled the cound of challed of the malled of the cortored the
#
#
#
#
#
#
#
#  temperature: 0.5
# f the malled of the cortored the
#
#
#
#
#
#
# and mas and the the wand word the gasing had the farle a corice.
#
# "the contoren dow the parnice of
#  temperature: 1.0
# ice.
#
# "the contoren dow the parnice of the byar. "lyspull corsice od, m. tored as anloored waand the ounder anmsolle, dous in medoull
# gwon
#  temperature: 1.2
# e ounder anmsolle, dous in medoull
# gwon, alloved n ewhe spriigd jout it ovect, dombe ain. "eovtr ppllce, omed, swann beckitily. "laig conc,
#  epoch 17
# 237/237 [==============================] - 24s 101ms/step - loss: 2.0021
# Generating with seed:  "ped in a salvador dali painting, he thou"
#
#  temperature: 0.2
# ped in a salvador dali painting, he though the cartared the conter and the chis and the cort the cort and the coll and the mast the more the
#  temperature: 0.5
# t and the coll and the mast the more the cortsing, langdon gand of to a the aging his imager show stong the grops and
# "smound a fache
#
# the
#  temperature: 1.0
# ong the grops and
# "smound a fache
#
# the mole stoost notred yismith mowhing to higd pelt nepsicinc, ley byey s3ut emes propcliousd galn a sp
#  temperature: 1.2
# ley byey s3ut emes propcliousd galn a spricked
# dook totee dy
# anogrumen toflerg of venvet gilhsss'ssimalf es
# stundeloy's e dotls who pinsr
#  epoch 18
# 237/237 [==============================] - 24s 100ms/step - loss: 1.9870
# Generating with seed:  "angdon," fache said, "certainly a man li"
#
#  temperature: 0.2
# angdon," fache said, "certainly a man list of the paller the palled the salle had he serist of the mallered the mandered the langdon sald hi
#  temperature: 0.5
# allered the mandered the langdon sald his a ferthe the palted the lagre had his had had
# the monthed the mallen on the ported he her was he
#  temperature: 1.0
#  the mallen on the ported he her was he oher was a farla't thourt ha the lover war the he clooros. "won they arlitheas of mimftrour warchad
#  temperature: 1.2
# won they arlitheas of mimftrour warchad that talisk-wasld, ho dursted hay xpore?" save a colllokem bobi the calles 8pud ventals no hald an.
#  epoch 19
# 237/237 [==============================] - 23s 97ms/step - loss: 1.9710
# Generating with seed:  "ian?" fache's tone came with a tinge of "
#
#  temperature: 0.2
# ian?" fache's tone came with a tinge of the porise the mont of the
# contion as a sumber at had had sime the corition and the mand of the
#
# l
#  temperature: 0.5
# ime the corition and the mand of the
#
# langdon saing the and nos ponting wand collowed the right now his has a cald to ches on a phish ow he
#  temperature: 1.0
#  his has a cald to ches on a phish ow her geat.n."
#
# "ec. le pie wordens, ap oristwamland ladrd.
# jas drate "'t row. fommite in s sus ait to
#  temperature: 1.2
# s drate "'t row. fommite in s sus ait tod au8 or wokkey dhale simmuulled,. on pmalle, alyos mow, preast raaserceecruwite thais fir beucutong
#  epoch 20
# 237/237 [==============================] - 25s 104ms/step - loss: 1.9544
# Generating with seed:  "nd racism in the united states, and yet "
#
#  temperature: 0.2
# nd racism in the united states, and yet the corred had he war seand of the called and he store the penting the cart of the
# canted the carn
#  temperature: 0.5
# enting the cart of the
# canted the carn and and man the caller ho he ren dom of the sure
#
# wal shen ented the rus and the prost on pall and
#  temperature: 1.0
# ented the rus and the prost on pall and poun. uncenatry, mandory eden en thing tarked his elypto sated lag kats, he renthened to rostine on
#  temperature: 1.2
# ed lag kats, he renthened to rostine on the could,
# nogry plloben gad tutrysuxu sevenk, liownk, ant in whard seeavee stankripal 9wodkrevpoli
#  epoch 21
# 237/237 [==============================] - 25s 106ms/step - loss: 1.9403
# Generating with seed:  "rble to be compatible
# with the honey-co"
#
#  temperature: 0.2
# rble to be compatible
# with the honey-conting the sime the store the stant of the
# contare the sour of the
#
# langron the ward of the corrtor
#  temperature: 0.5
# of the
#
# langron the ward of the corrtore seate and he derrice and bely his a prepprer botthe had betorion a port of eracing an the was belt
#  temperature: 1.0
# torion a port of eracing an the was beltow minhtod worly.
#
# seryice wfre stacr. "thee conclope the nest the chat of inscblics ffot hal gopre
#  temperature: 1.2
# est the chat of inscblics ffot hal goprec" eng"th mand treauch bractald conurder, suived onored, ruoligrint
# loget an the nelscers."
#
# "tuac
#  epoch 22
# 237/237 [==============================] - 24s 103ms/step - loss: 1.9246
# Generating with seed:  "showed
# no signs of letting up. "and mr."
#
#  temperature: 0.2
# showed
# no signs of letting up. "and mr.
#
# the langdon said de ment of the
# cort of the
# chall of the preather and the
# cont of the moll of
#  temperature: 0.5
# e preather and the
# cont of the moll of the reved the mels the pring of him sour a me pent
# the langdon hald vered sind his y a ben to the c
#  temperature: 1.0
# don hald vered sind his y a ben to the crekss.
#
# ""in his jaze, loth reas, und blood, veerige an
# reverth. les corke.
#
# "ya parets offly it,
#  temperature: 1.2
# verth. les corke.
#
# "ya parets offly it, his fowhryem. old gvood aidh havel ow whis — laingrente dribeys ace agacerly havonel reimitiog?"
#
#
#  epoch 23
# 237/237 [==============================] - 25s 106ms/step - loss: 1.9100
# Generating with seed:  "her," the bishop would patiently reply. "
#
#  temperature: 0.2
# her," the bishop would patiently reply.
#
# "she langdon sainiere sainiere the reather and the corre and the corre the more the corre the
#
# th
#  temperature: 0.5
# nd the corre the more the corre the
#
# the viche's a on gowring of the mest wist the aller her on he mare to a lourd on his elige simbery in
#  temperature: 1.0
# mare to a lourd on his elige simbery in frallangy agiss! stingatl sesised cquailimexse dopvines.
# canes derir ever.
#
#
# elently tale sauve al
#  temperature: 1.2
# nes derir ever.
#
#
# elently tale sauve alkly foun orucled of
# stringty. icen ure firtiove& thobyeis as w-cenher,"
#
# whoy haveilezes"
#
# benied
#  epoch 24
# 237/237 [==============================] - 24s 101ms/step - loss: 1.8943
# Generating with seed:  "estion seemed odd. "mr. sauniere did," l"
#
#  temperature: 0.2
# estion seemed odd. "mr. sauniere did," langdon sadded the corted the mare and the call of the langdon stown the
# langdon starting the chorri
#  temperature: 0.5
# n stown the
# langdon starting the chorricn — the
#
#
# silating the crondered his saunt and storict of the bling
# the revile sagen the mar as h
#  temperature: 1.0
# the bling
# the revile sagen the mar as hale souveringd salain, serced."
#
# nots at ntw and hes piches sari's oftamm guteres deeccle,
# temptlo
#  temperature: 1.2
#  sari's oftamm guteres deeccle,
# temptlo gloid, and to whe bord old sewrity kimpelttert ko the dross forneatquised itt the incrembliclly der
#  epoch 25
# 237/237 [==============================] - 24s 103ms/step - loss: 1.8804
# Generating with seed:  "ringarosa smiled. "then we are close."
# "
#
#  temperature: 0.2
# ringarosa smiled. "then we are close."
#
# "the coratored and the courder of the cound on the
# goon's galles of the mother and the corrtored a
#  temperature: 0.5
# galles of the mother and the corrtored an wis in the proofecle sueded an he
# inevered the most of the
# contare of simele made to the bover o
#  temperature: 1.0
# e
# contare of simele made to the bover ood, he seare colrige sebmioust wat collast, hn mithoncied tien he ware to fut aksiguts yes fremmopti
#  temperature: 1.2
# en he ware to fut aksiguts yes fremmopting, loved kiid spembelicitize of inth in — fat
# ate mutton veinad sault zeed
# mad breligeza's persef
#  epoch 26
# 237/237 [==============================] - 24s 101ms/step - loss: 1.8652
# Generating with seed:  "r understanding.
#
# langdon had hung enou"
#
#  temperature: 0.2
# r understanding.
#
# langdon had hung enound the
# contare had been
#
# the corrion and the
# courtored and the could and the was a the could a fo
#  temperature: 0.5
# d the could and the was a the could a for mored."
#
# sarriene doont off cous the
# goss to and the reas mare sarkie the inture the wno her and
#  temperature: 1.0
# s mare sarkie the inture the wno her and ftoon mabboul emoscention. ale covite wardmone vimce dequd hem."
#
#
#
# vayrunats if fares, what, whe
#  temperature: 1.2
# hem."
#
#
#
# vayrunats if fares, what, whe
# bold houn wary in in enly, fretigi's boubf
# loirismilem. t u&nggon clacjednolijggordseephe. at hime
#  epoch 27
# 237/237 [==============================] - 23s 98ms/step - loss: 1.8509
# Generating with seed:  "teen or
# twenty minutes. he was obviousl"
#
#  temperature: 0.2
# teen or
# twenty minutes. he was obviously the wark had he whold the seano and the langdon sald a corround and the collourd and the pentaring
#  temperature: 0.5
# round and the collourd and the pentaring his id in the with the sound of the
# conurre peried the sared his
# briof arrall arred, the side a t
#  temperature: 1.0
# ed his
# briof arrall arred, the side a they seed him his of of bimee, the wenonth warked begond to his hatcen ncaiting," hes whil horee dely
#  temperature: 1.2
# is hatcen ncaiting," hes whil horee dely. hhig cima vases. chelingawind lfangde's. acmungen clard had thes. noussing thinekol yele
# dequcama
#  epoch 28
# 237/237 [==============================] - 24s 103ms/step - loss: 1.8361
# Generating with seed:  "tructed of exactly 666
# panes of glass —"
#
#  temperature: 0.2
# tructed of exactly 666
# panes of glass — the
# contarre
# alligat for showe of the corred and booked and to the mork of the moun of the more a
#  temperature: 0.5
# nd to the mork of the moun of the more and wish seade to prestite a forsting the furtheng to the molloogds, and the galler,
# secous off ous
#  temperature: 1.0
# loogds, and the galler,
# secous off ous atess, lorrtwold shighed-ingto ey the yoranoods an harke ny
# on, his — over forzopin ove
# faringengy
#  temperature: 1.2
#
# on, his — over forzopin ove
# faringengy bod,s pore malling on's gexor. enstry. thas had yines a wintatiry."
#
# "yh?. lifulin thiaci? grossst
#  epoch 29
# 237/237 [==============================] - 25s 104ms/step - loss: 1.8228
# Generating with seed:  "e had learned to find peace in the calmi"
#
#  temperature: 0.2
# e had learned to find peace in the calming his in the puriting the conded sard, and the courded staded and his a fache said, and the called
#  temperature: 0.5
# ed and his a fache said, and the called stowe had bond was his and and the carred alle, the was the hat a the sunder. "elong and in a coriti
#  temperature: 1.0
# hat a the sunder. "elong and in a coriting's vercouploo deomint bound the
# cilabe a the couldor forvealan yrous, "iod, am withing wo the ida
#  temperature: 1.2
# ealan yrous, "iod, am withing wo the idares, " vefpilis, jullton lise-sood, foressw? poresangen fouldoring the eave frathen." toskonw?" crib
